# %% [markdown]
# # Exploratory Data Analysis of IPL-Matches(2008-2022)
# As you all know Cricket is a sport played and watched by millions of people around the world but Indians are mad about cricket. Cricket is played in our streets. We like it so much. People in india are crazy about the game. Cricket is a Gentlemen Game , As a cricket lover, I decided to analyze the data of IPL matches. Why IPL match? Because cricket is not a game of any specific country or a nation, I love Indian league IPL .So, that why I shall anlyze the data of IPL matches from 2008 to 2022.
#
# I found IPL matches (2008-2022) dataset from kaggle.
# - Here is the link of IPL matches Dataset: https://www.kaggle.com/datasets/vora1011/ipl-2008-to-2021-all-match-dataset?select=IPL_Matches_2008_2022.csv

# %% [markdown]
# ## Data Selection and Installing
# First we will select appropriate dataset from kaggle which I have done. You can check it at this link: https://www.kaggle.com/datasets/vora1011/ipl-2008-to-2021-all-match-dataset?select=IPL_Matches_2008_2022.csv. To download our dataset we have to install opendataset library by pip install command.

# %%
dataset_url = 'https://www.kaggle.com/datasets/vora1011/ipl-2008-to-2021-all-match-dataset?select=IPL_Matches_2008_2022.csv'

# %% [markdown]
# ## Essential Libraries for this Project
# Lets import essential libraries for this project

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
#settings
sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Analysing IPL match dataset

# %% [markdown]
# ## Data Preparation and Cleaning
# First, we load our dataset into DataFrame and see our DataFrame some first and last rows to overview of dataset

# %%
df = pd.read_csv('IPL_Matches_2008_2022.csv')

# %%
df.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %% [markdown]
# By looking at the dataset we can see that our dataset contains many rows and columns. The dataset includes **MatchNumber**, **Team1**, **Team2**, **Venue**, **Team1Players**, **Team2Players**, **Umpire1** and **Umpire2** Data which gives us information about where match held, which teams played a match and about team players, about umpires also and information about **winning team** and win stats.

# %%
df.shape
# Out:
# (950, 20)

# %% [markdown]
# There is 950 rows and 20 columns in our Dataset

# %% [markdown]
# #city , supperover , winningteam,margin,method,play of match

# %%
df.head(3)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 0         N               Gujarat Titans  Wickets     7.0    NaN
# 1         N             Rajasthan Royals  Wickets     7.0    NaN
# 2         N  Royal Challengers Bangalore     Runs    14.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
#                                         Team2Players        Umpire1  \
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2  ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
#
#        Umpire2
# 0  Nitin Menon
# 1  Nitin Menon
# 2     MA Gough

# %%
df['WonBy'].nunique()
# Out:
# 4

# %%
df.value_counts()
# Out:
# ID       City           Date        Season   MatchNumber  Team1                        Team2                        Venue                                                TossWinner                   TossDecision  SuperOver  WinningTeam                  WonBy    Margin  method  Player_of_Match   Team1Players                                                                                                                                               Team2Players                                                                                                                                                 Umpire1                Umpire2
# 336022   Delhi          2008-05-17  2007/08  40           Delhi Daredevils             Kings XI Punjab              Feroz Shah Kotla                                     Delhi Daredevils             bat           N          Kings XI Punjab              Runs     6.0     D/L     DPMD Jayawardene  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'TM Dilshan', 'MF Maharoof', 'Shoaib Malik', 'PJ Sangwan', 'KD Karthik', 'A Mishra', 'R Bhatia', 'GD McGrath']       ['SE Marsh', 'JR Hopes', 'Yuvraj Singh', 'LA Pomersbach', 'DPMD Jayawardene', 'IK Pathan', 'RR Powar', 'PP Chawla', 'U Kaul', 'S Sreesanth', 'VRV Singh']    AV Jayaprakash         RE Koertzen        1
# 336025   Kolkata        2008-05-18  2007/08  41           Kolkata Knight Riders        Chennai Super Kings          Eden Gardens                                         Kolkata Knight Riders        bat           N          Chennai Super Kings          Runs     3.0     D/L     M Ntini           ['Salman Butt', 'Mohammad Hafeez', 'SC Ganguly', 'DB Das', 'DJ Hussey', 'LR Shukla', 'WP Saha', 'AB Agarkar', 'I Sharma', 'AB Dinda', 'Shoaib Akhtar']     ['PA Patel', 'SP Fleming', 'S Vidyut', 'SK Raina', 'S Badrinath', 'MS Dhoni', 'JA Morkel', 'MS Gony', 'L Balaji', 'M Muralitharan', 'M Ntini']               Asad Rauf              K Hariharan        1
# 392183   Cape Town      2009-04-19  2009     3            Delhi Daredevils             Kings XI Punjab              Newlands                                             Delhi Daredevils             field         N          Delhi Daredevils             Wickets  10.0    D/L     DL Vettori        ['G Gambhir', 'V Sehwag', 'TM Dilshan', 'AB de Villiers', 'MK Tiwary', 'KD Karthik', 'DP Nannes', 'DL Vettori', 'VY Mahesh', 'AM Salvi', 'PJ Sangwan']     ['RS Bopara', 'K Goel', 'Yuvraj Singh', 'KC Sangakkara', 'DPMD Jayawardene', 'IK Pathan', 'PP Chawla', 'T Kohli', 'VS Malik', 'VRV Singh', 'YA Abdulla']     MR Benson              SD Ranade          1
# 1136578  Kolkata        2018-04-21  2018     18           Kolkata Knight Riders        Kings XI Punjab              Eden Gardens                                         Kings XI Punjab              field         N          Kings XI Punjab              Wickets  9.0     D/L     KL Rahul          ['CA Lynn', 'SP Narine', 'RV Uthappa', 'N Rana', 'KD Karthik', 'AD Russell', 'Shubman Gill', 'TK Curran', 'PP Chawla', 'Shivam Mavi', 'Kuldeep Yadav']     ['KL Rahul', 'CH Gayle', 'MA Agarwal', 'KK Nair', 'AJ Finch', 'Yuvraj Singh', 'R Ashwin', 'AJ Tye', 'BB Sran', 'Mujeeb Ur Rahman', 'AS Rajpoot']             A Deshmukh             C Shamshuddin      1
# 1136592  Delhi          2018-05-02  2018     32           Delhi Daredevils             Rajasthan Royals             Arun Jaitley Stadium                                 Rajasthan Royals             field         N          Delhi Daredevils             Runs     4.0     D/L     RR Pant           ['PP Shaw', 'C Munro', 'SS Iyer', 'RR Pant', 'GJ Maxwell', 'V Shankar', 'LE Plunkett', 'A Mishra', 'S Nadeem', 'Avesh Khan', 'TA Boult']                   ['DJM Short', 'JC Buttler', 'SV Samson', 'BA Stokes', 'RA Tripathi', 'K Gowtham', 'JC Archer', 'AM Rahane', 'JD Unadkat', 'DS Kulkarni', 'S Gopal']          CK Nandan              VK Sharma          1
# Name: count, dtype: int64

# %%
df.describe()['Margin']
# Out:
# count    932.000000
# mean      17.056867
# std       21.633109
# min        1.000000
# 25%        6.000000
# 50%        8.000000
# 75%       19.000000
# max      146.000000
# Name: Margin, dtype: float64

# %%
# groupby
df.groupby('WonBy')['Margin'].mean()
# Out:
# WonBy
# NoResults          NaN
# Runs         30.073286
# SuperOver          NaN
# Wickets       6.239686
# Name: Margin, dtype: float64

# %%
# groupby
df.groupby('WonBy')['Margin'].median()
# Out:
# WonBy
# NoResults     NaN
# Runs         22.0
# SuperOver     NaN
# Wickets       6.0
# Name: Margin, dtype: float64

# %% [markdown]
# ### I cant se about mean,median and other statistical value > bcoZ depended on wonby col(runs,wickets,superover,noresult)

# %%
df.nunique()
# Out:
# ID                 950
# City                33
# Date               706
# Season              15
# MatchNumber         80
# Team1               18
# Team2               18
# Venue               49
# TossWinner          18
# TossDecision         2
# SuperOver            2
# WinningTeam         18
# WonBy                4
# Margin              94
# method               1
# Player_of_Match    262
# Team1Players       932
# Team2Players       937
# Umpire1             58
# Umpire2             60
# dtype: int64

# %% [markdown]
# #### The above table provides us with very useful information. By above table we can see that as of 2022, there have been 15 seasons of IPL tournament hosted by 33 cities. Although, 18 teams have played and 262 Players become player of match in past seasons of IPL.

# %%
df.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
print("Total Null Cells",df.isnull().sum().sum())
df.isnull().sum()
# Out:
# Total Null Cells 1012
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
df.Date.dtype #
# Out:
# dtype('O')

# %%
df.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
df.Date
# Out:
# 0      2022-05-29
# 1      2022-05-27
# 2      2022-05-25
# 3      2022-05-24
# 4      2022-05-22
#           ...
# 945    2008-04-20
# 946    2008-04-20
# 947    2008-04-19
# 948    2008-04-19
# 949    2008-04-18
# Name: Date, Length: 950, dtype: object

# %% [markdown]
# In our DataFrame the date should be a string that represent date for future work with date. Let's convert all cells in **Date** column to dates. Pandas have **datetime()** method for this.

# %%
pd.to_datetime(df['Date'])
# Out:
# 0     2022-05-29
# 1     2022-05-27
# 2     2022-05-25
# 3     2022-05-24
# 4     2022-05-22
#          ...
# 945   2008-04-20
# 946   2008-04-20
# 947   2008-04-19
# 948   2008-04-19
# 949   2008-04-18
# Name: Date, Length: 950, dtype: datetime64[ns]

# %%
df['Date']
# Out:
# 0      2022-05-29
# 1      2022-05-27
# 2      2022-05-25
# 3      2022-05-24
# 4      2022-05-22
#           ...
# 945    2008-04-20
# 946    2008-04-20
# 947    2008-04-19
# 948    2008-04-19
# 949    2008-04-18
# Name: Date, Length: 950, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
#  16  Team1Players     950 non-null    object
#  17  Team2Players     950 non-null    object
#  18  Umpire1          950 non-null    object
#  19  Umpire2          950 non-null    object
# dtypes: float64(1), int64(1), object(18)
# memory usage: 148.6+ KB

# %%
df['Date'][0]
# Out:
# '2022-05-29'

# %%
df['Date']
# Out:
# 0      2022-05-29
# 1      2022-05-27
# 2      2022-05-25
# 3      2022-05-24
# 4      2022-05-22
#           ...
# 945    2008-04-20
# 946    2008-04-20
# 947    2008-04-19
# 948    2008-04-19
# 949    2008-04-18
# Name: Date, Length: 950, dtype: object

# %% [markdown]
# Now, we will clean empty cells, wrong data and unusual data. We will also check any duplicate data in our dataset.

# %%
### ceking duplicate rows
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 945    False
# 946    False
# 947    False
# 948    False
# 949    False
# Length: 950, dtype: bool

# %%
### ceking duplicate rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# > Thera are no duplicate within the dateset

# %%
df.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
df.value_counts()
# Out:
# ID       City           Date        Season   MatchNumber  Team1                        Team2                        Venue                                                TossWinner                   TossDecision  SuperOver  WinningTeam                  WonBy    Margin  method  Player_of_Match   Team1Players                                                                                                                                               Team2Players                                                                                                                                                 Umpire1                Umpire2
# 336022   Delhi          2008-05-17  2007/08  40           Delhi Daredevils             Kings XI Punjab              Feroz Shah Kotla                                     Delhi Daredevils             bat           N          Kings XI Punjab              Runs     6.0     D/L     DPMD Jayawardene  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'TM Dilshan', 'MF Maharoof', 'Shoaib Malik', 'PJ Sangwan', 'KD Karthik', 'A Mishra', 'R Bhatia', 'GD McGrath']       ['SE Marsh', 'JR Hopes', 'Yuvraj Singh', 'LA Pomersbach', 'DPMD Jayawardene', 'IK Pathan', 'RR Powar', 'PP Chawla', 'U Kaul', 'S Sreesanth', 'VRV Singh']    AV Jayaprakash         RE Koertzen        1
# 336025   Kolkata        2008-05-18  2007/08  41           Kolkata Knight Riders        Chennai Super Kings          Eden Gardens                                         Kolkata Knight Riders        bat           N          Chennai Super Kings          Runs     3.0     D/L     M Ntini           ['Salman Butt', 'Mohammad Hafeez', 'SC Ganguly', 'DB Das', 'DJ Hussey', 'LR Shukla', 'WP Saha', 'AB Agarkar', 'I Sharma', 'AB Dinda', 'Shoaib Akhtar']     ['PA Patel', 'SP Fleming', 'S Vidyut', 'SK Raina', 'S Badrinath', 'MS Dhoni', 'JA Morkel', 'MS Gony', 'L Balaji', 'M Muralitharan', 'M Ntini']               Asad Rauf              K Hariharan        1
# 392183   Cape Town      2009-04-19  2009     3            Delhi Daredevils             Kings XI Punjab              Newlands                                             Delhi Daredevils             field         N          Delhi Daredevils             Wickets  10.0    D/L     DL Vettori        ['G Gambhir', 'V Sehwag', 'TM Dilshan', 'AB de Villiers', 'MK Tiwary', 'KD Karthik', 'DP Nannes', 'DL Vettori', 'VY Mahesh', 'AM Salvi', 'PJ Sangwan']     ['RS Bopara', 'K Goel', 'Yuvraj Singh', 'KC Sangakkara', 'DPMD Jayawardene', 'IK Pathan', 'PP Chawla', 'T Kohli', 'VS Malik', 'VRV Singh', 'YA Abdulla']     MR Benson              SD Ranade          1
# 392186   Durban         2009-04-21  2009     6            Kings XI Punjab              Kolkata Knight Riders        Kingsmead                                            Kolkata Knight Riders        field         N          Kolkata Knight Riders        Runs     11.0    D/L     CH Gayle          ['RS Bopara', 'K Goel', 'IK Pathan', 'KC Sangakkara', 'Yuvraj Singh', 'DPMD Jayawardene', 'T Kohli', 'PP Chawla', 'VS Malik', 'VRV Singh', 'YA Abdulla']   ['BB McCullum', 'CH Gayle', 'BJ Hodge', 'SC Ganguly', 'Yashpal Singh', 'A Chopra', 'MC Henriques', 'LR Shukla', 'I Sharma', 'M Kartik', 'AB Dinda']          DJ Harper              SD Ranade          1
# 1136578  Kolkata        2018-04-21  2018     18           Kolkata Knight Riders        Kings XI Punjab              Eden Gardens                                         Kings XI Punjab              field         N          Kings XI Punjab              Wickets  9.0     D/L     KL Rahul          ['CA Lynn', 'SP Narine', 'RV Uthappa', 'N Rana', 'KD Karthik', 'AD Russell', 'Shubman Gill', 'TK Curran', 'PP Chawla', 'Shivam Mavi', 'Kuldeep Yadav']     ['KL Rahul', 'CH Gayle', 'MA Agarwal', 'KK Nair', 'AJ Finch', 'Yuvraj Singh', 'R Ashwin', 'AJ Tye', 'BB Sran', 'Mujeeb Ur Rahman', 'AS Rajpoot']             A Deshmukh             C Shamshuddin      1
# 1136592  Delhi          2018-05-02  2018     32           Delhi Daredevils             Rajasthan Royals             Arun Jaitley Stadium                                 Rajasthan Royals             field         N          Delhi Daredevils             Runs     4.0     D/L     RR Pant           ['PP Shaw', 'C Munro', 'SS Iyer', 'RR Pant', 'GJ Maxwell', 'V Shankar', 'LE Plunkett', 'A Mishra', 'S Nadeem', 'Avesh Khan', 'TA Boult']                   ['DJM Short', 'JC Buttler', 'SV Samson', 'BA Stokes', 'RA Tripathi', 'K Gowtham', 'JC Archer', 'AM Rahane', 'JD Unadkat', 'DS Kulkarni', 'S Gopal']          CK Nandan              VK Sharma          1
# Name: count, dtype: int64

# %%
df['City'].value_counts()
# Out:
# City
# Mumbai            159
# Kolkata            79
# Delhi              78
# Chennai            67
# Bangalore          65
# Hyderabad          64
# Chandigarh         56
# Pune               51
# Jaipur             47
# Abu Dhabi          37
# Ahmedabad          19
# Bengaluru          15
# Durban             15
# Visakhapatnam      13
# Dubai              13
# Centurion          12
# Sharjah            10
# Rajkot             10
# Navi Mumbai         9
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Port Elizabeth      7
# Cuttack             7
# Ranchi              7
# Cape Town           7
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
len(df['City'].value_counts())
# Out:
# 33

# %%
df['City'].value_counts().head(33)
# Out:
# City
# Mumbai            159
# Kolkata            79
# Delhi              78
# Chennai            67
# Bangalore          65
# Hyderabad          64
# Chandigarh         56
# Pune               51
# Jaipur             47
# Abu Dhabi          37
# Ahmedabad          19
# Bengaluru          15
# Durban             15
# Visakhapatnam      13
# Dubai              13
# Centurion          12
# Sharjah            10
# Rajkot             10
# Navi Mumbai         9
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Port Elizabeth      7
# Cuttack             7
# Ranchi              7
# Cape Town           7
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
for City in df['City'].value_counts().index:
    print(City)
# Out:
# Mumbai
# Kolkata
# Delhi
# Chennai
# Bangalore
# Hyderabad
# Chandigarh
# Pune
# Jaipur
# Abu Dhabi
# Ahmedabad
# Bengaluru
# Durban
# Visakhapatnam
# Dubai
# Centurion
# Sharjah
# Rajkot
# Navi Mumbai
# Indore
# Dharamsala
# Johannesburg
# Port Elizabeth
# Cuttack
# Ranchi
# Cape Town
# Raipur
# Kochi
# Kanpur
# Nagpur
# Kimberley
# East London
# Bloemfontein

# %%
df['City'].value_counts().sort_index()
# Out:
# City
# Abu Dhabi          37
# Ahmedabad          19
# Bangalore          65
# Bengaluru          15
# Bloemfontein        2
# Cape Town           7
# Centurion          12
# Chandigarh         56
# Chennai            67
# Cuttack             7
# Delhi              78
# Dharamsala          9
# Dubai              13
# Durban             15
# East London         3
# Hyderabad          64
# Indore              9
# Jaipur             47
# Johannesburg        8
# Kanpur              4
# Kimberley           3
# Kochi               5
# Kolkata            79
# Mumbai            159
# Nagpur              3
# Navi Mumbai         9
# Port Elizabeth      7
# Pune               51
# Raipur              6
# Rajkot             10
# Ranchi              7
# Sharjah            10
# Visakhapatnam      13
# Name: count, dtype: int64

# %%
df['City'].replace
# Out:
# <bound method NDFrame.replace of 0       Ahmedabad
# 1       Ahmedabad
# 2         Kolkata
# 3         Kolkata
# 4          Mumbai
#           ...
# 945       Kolkata
# 946        Mumbai
# 947         Delhi
# 948    Chandigarh
# 949     Bangalore
# Name: City, Length: 950, dtype: object>

# %%
f1 = df['City']=='Bangalore'

# %%
df[f1].replace('')
# Out:
#           ID       City        Date   Season  MatchNumber  \
# 315  1082649  Bangalore  2017-05-19     2017  Qualifier 2
# 316  1082648  Bangalore  2017-05-17     2017   Eliminator
# 327  1082636  Bangalore  2017-05-07     2017           46
# 331  1082633  Bangalore  2017-05-05     2017           43
# 343  1082621  Bangalore  2017-04-27     2017           31
# ..       ...        ...         ...      ...          ...
# 925   336006  Bangalore  2008-05-05  2007/08           25
# 928   336034  Bangalore  2008-05-03  2007/08           21
# 935   335996  Bangalore  2008-04-28  2007/08           15
# 939   335992  Bangalore  2008-04-26  2007/08           12
# 949   335982  Bangalore  2008-04-18  2007/08            1
#
#                            Team1                  Team2  \
# 315               Mumbai Indians  Kolkata Knight Riders
# 316          Sunrisers Hyderabad  Kolkata Knight Riders
# 327  Royal Challengers Bangalore  Kolkata Knight Riders
# 331  Royal Challengers Bangalore        Kings XI Punjab
# 343  Royal Challengers Bangalore          Gujarat Lions
# ..                           ...                    ...
# 925  Royal Challengers Bangalore        Kings XI Punjab
# 928  Royal Challengers Bangalore        Deccan Chargers
# 935  Royal Challengers Bangalore    Chennai Super Kings
# 939  Royal Challengers Bangalore       Rajasthan Royals
# 949  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                      Venue                   TossWinner TossDecision  \
# 315  M Chinnaswamy Stadium               Mumbai Indians        field
# 316  M Chinnaswamy Stadium        Kolkata Knight Riders        field
# 327  M Chinnaswamy Stadium        Kolkata Knight Riders        field
# 331  M Chinnaswamy Stadium  Royal Challengers Bangalore        field
# 343  M Chinnaswamy Stadium                Gujarat Lions        field
# ..                     ...                          ...          ...
# 925  M Chinnaswamy Stadium              Kings XI Punjab        field
# 928  M Chinnaswamy Stadium              Deccan Chargers        field
# 935  M Chinnaswamy Stadium          Chennai Super Kings          bat
# 939  M Chinnaswamy Stadium             Rajasthan Royals        field
# 949  M Chinnaswamy Stadium  Royal Challengers Bangalore        field
#
#     SuperOver                  WinningTeam    WonBy  Margin method  \
# 315         N               Mumbai Indians  Wickets     6.0    NaN
# 316         N        Kolkata Knight Riders  Wickets     7.0    D/L
# 327         N        Kolkata Knight Riders  Wickets     6.0    NaN
# 331         N              Kings XI Punjab     Runs    19.0    NaN
# 343         N                Gujarat Lions  Wickets     7.0    NaN
# ..        ...                          ...      ...     ...    ...
# 925         N              Kings XI Punjab  Wickets     6.0    NaN
# 928         N  Royal Challengers Bangalore     Runs     3.0    NaN
# 935         N          Chennai Super Kings     Runs    13.0    NaN
# 939         N             Rajasthan Royals  Wickets     7.0    NaN
# 949         N        Kolkata Knight Riders     Runs   140.0    NaN
#
#      Player_of_Match                                       Team1Players  \
# 315        KV Sharma  ['LMP Simmons', 'PA Patel', 'AT Rayudu', 'RG S...
# 316  NM Coulter-Nile  ['DA Warner', 'S Dhawan', 'KS Williamson', 'Yu...
# 327        SP Narine  ['CH Gayle', 'Mandeep Singh', 'V Kohli', 'AB d...
# 331   Sandeep Sharma  ['Mandeep Singh', 'CH Gayle', 'V Kohli', 'AB d...
# 343           AJ Tye  ['CH Gayle', 'V Kohli', 'AB de Villiers', 'TM ...
# ..               ...                                                ...
# 925      S Sreesanth  ['W Jaffer', 'V Kohli', 'CL White', 'JH Kallis...
# 928          P Kumar  ['B Chipli', 'W Jaffer', 'V Kohli', 'JH Kallis...
# 935         MS Dhoni  ['B Chipli', 'W Jaffer', 'LRPL Taylor', 'JH Ka...
# 939        SR Watson  ['S Chanderpaul', 'R Dravid', 'LRPL Taylor', '...
# 949      BB McCullum  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                           Team2Players       Umpire1  \
# 315  ['CA Lynn', 'SP Narine', 'G Gambhir', 'RV Utha...      NJ Llong
# 316  ['RV Uthappa', 'CA Lynn', 'YK Pathan', 'G Gamb...  AK Chaudhary
# 327  ['CA Lynn', 'SP Narine', 'C de Grandhomme', 'G...   AY Dandekar
# 331  ['HM Amla', 'MJ Guptill', 'SE Marsh', 'M Vohra...   CB Gaffaney
# 343  ['Ishan Kishan', 'BB McCullum', 'SK Raina', 'A...  AK Chaudhary
# ..                                                 ...           ...
# 925  ['SE Marsh', 'JR Hopes', 'RR Sarwan', 'Yuvraj ...      SJ Davis
# 928  ['AC Gilchrist', 'VVS Laxman', 'HH Gibbs', 'RG...   BR Doctrove
# 935  ['PA Patel', 'ML Hayden', 'MEK Hussey', 'SK Ra...   BR Doctrove
# 939  ['GC Smith', 'M Rawat', 'YK Pathan', 'SR Watso...     MR Benson
# 949  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...     Asad Rauf
#
#            Umpire2
# 315    Nitin Menon
# 316    Nitin Menon
# 327  C Shamshuddin
# 331  C Shamshuddin
# 343  C Shamshuddin
# ..             ...
# 925    BR Doctrove
# 928     SL Shastri
# 935      RB Tiffin
# 939      IL Howell
# 949    RE Koertzen
#
# [65 rows x 20 columns]

# %%
df[f1].replace('Bangalore','Bangalore')
# Out:
#           ID       City        Date   Season  MatchNumber  \
# 315  1082649  Bangalore  2017-05-19     2017  Qualifier 2
# 316  1082648  Bangalore  2017-05-17     2017   Eliminator
# 327  1082636  Bangalore  2017-05-07     2017           46
# 331  1082633  Bangalore  2017-05-05     2017           43
# 343  1082621  Bangalore  2017-04-27     2017           31
# ..       ...        ...         ...      ...          ...
# 925   336006  Bangalore  2008-05-05  2007/08           25
# 928   336034  Bangalore  2008-05-03  2007/08           21
# 935   335996  Bangalore  2008-04-28  2007/08           15
# 939   335992  Bangalore  2008-04-26  2007/08           12
# 949   335982  Bangalore  2008-04-18  2007/08            1
#
#                            Team1                  Team2  \
# 315               Mumbai Indians  Kolkata Knight Riders
# 316          Sunrisers Hyderabad  Kolkata Knight Riders
# 327  Royal Challengers Bangalore  Kolkata Knight Riders
# 331  Royal Challengers Bangalore        Kings XI Punjab
# 343  Royal Challengers Bangalore          Gujarat Lions
# ..                           ...                    ...
# 925  Royal Challengers Bangalore        Kings XI Punjab
# 928  Royal Challengers Bangalore        Deccan Chargers
# 935  Royal Challengers Bangalore    Chennai Super Kings
# 939  Royal Challengers Bangalore       Rajasthan Royals
# 949  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                      Venue                   TossWinner TossDecision  \
# 315  M Chinnaswamy Stadium               Mumbai Indians        field
# 316  M Chinnaswamy Stadium        Kolkata Knight Riders        field
# 327  M Chinnaswamy Stadium        Kolkata Knight Riders        field
# 331  M Chinnaswamy Stadium  Royal Challengers Bangalore        field
# 343  M Chinnaswamy Stadium                Gujarat Lions        field
# ..                     ...                          ...          ...
# 925  M Chinnaswamy Stadium              Kings XI Punjab        field
# 928  M Chinnaswamy Stadium              Deccan Chargers        field
# 935  M Chinnaswamy Stadium          Chennai Super Kings          bat
# 939  M Chinnaswamy Stadium             Rajasthan Royals        field
# 949  M Chinnaswamy Stadium  Royal Challengers Bangalore        field
#
#     SuperOver                  WinningTeam    WonBy  Margin method  \
# 315         N               Mumbai Indians  Wickets     6.0    NaN
# 316         N        Kolkata Knight Riders  Wickets     7.0    D/L
# 327         N        Kolkata Knight Riders  Wickets     6.0    NaN
# 331         N              Kings XI Punjab     Runs    19.0    NaN
# 343         N                Gujarat Lions  Wickets     7.0    NaN
# ..        ...                          ...      ...     ...    ...
# 925         N              Kings XI Punjab  Wickets     6.0    NaN
# 928         N  Royal Challengers Bangalore     Runs     3.0    NaN
# 935         N          Chennai Super Kings     Runs    13.0    NaN
# 939         N             Rajasthan Royals  Wickets     7.0    NaN
# 949         N        Kolkata Knight Riders     Runs   140.0    NaN
#
#      Player_of_Match                                       Team1Players  \
# 315        KV Sharma  ['LMP Simmons', 'PA Patel', 'AT Rayudu', 'RG S...
# 316  NM Coulter-Nile  ['DA Warner', 'S Dhawan', 'KS Williamson', 'Yu...
# 327        SP Narine  ['CH Gayle', 'Mandeep Singh', 'V Kohli', 'AB d...
# 331   Sandeep Sharma  ['Mandeep Singh', 'CH Gayle', 'V Kohli', 'AB d...
# 343           AJ Tye  ['CH Gayle', 'V Kohli', 'AB de Villiers', 'TM ...
# ..               ...                                                ...
# 925      S Sreesanth  ['W Jaffer', 'V Kohli', 'CL White', 'JH Kallis...
# 928          P Kumar  ['B Chipli', 'W Jaffer', 'V Kohli', 'JH Kallis...
# 935         MS Dhoni  ['B Chipli', 'W Jaffer', 'LRPL Taylor', 'JH Ka...
# 939        SR Watson  ['S Chanderpaul', 'R Dravid', 'LRPL Taylor', '...
# 949      BB McCullum  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                           Team2Players       Umpire1  \
# 315  ['CA Lynn', 'SP Narine', 'G Gambhir', 'RV Utha...      NJ Llong
# 316  ['RV Uthappa', 'CA Lynn', 'YK Pathan', 'G Gamb...  AK Chaudhary
# 327  ['CA Lynn', 'SP Narine', 'C de Grandhomme', 'G...   AY Dandekar
# 331  ['HM Amla', 'MJ Guptill', 'SE Marsh', 'M Vohra...   CB Gaffaney
# 343  ['Ishan Kishan', 'BB McCullum', 'SK Raina', 'A...  AK Chaudhary
# ..                                                 ...           ...
# 925  ['SE Marsh', 'JR Hopes', 'RR Sarwan', 'Yuvraj ...      SJ Davis
# 928  ['AC Gilchrist', 'VVS Laxman', 'HH Gibbs', 'RG...   BR Doctrove
# 935  ['PA Patel', 'ML Hayden', 'MEK Hussey', 'SK Ra...   BR Doctrove
# 939  ['GC Smith', 'M Rawat', 'YK Pathan', 'SR Watso...     MR Benson
# 949  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...     Asad Rauf
#
#            Umpire2
# 315    Nitin Menon
# 316    Nitin Menon
# 327  C Shamshuddin
# 331  C Shamshuddin
# 343  C Shamshuddin
# ..             ...
# 925    BR Doctrove
# 928     SL Shastri
# 935      RB Tiffin
# 939      IL Howell
# 949    RE Koertzen
#
# [65 rows x 20 columns]

# %% [markdown]
# Reenaming Team

# %%
df['Team1'].value_counts()
# Out:
# Team1
# Royal Challengers Bangalore    126
# Mumbai Indians                 112
# Chennai Super Kings            111
# Kolkata Knight Riders          105
# Kings XI Punjab                 92
# Rajasthan Royals                89
# Delhi Daredevils                85
# Sunrisers Hyderabad             69
# Deccan Chargers                 39
# Delhi Capitals                  29
# Pune Warriors                   23
# Punjab Kings                    18
# Gujarat Lions                   16
# Lucknow Super Giants             8
# Gujarat Titans                   7
# Rising Pune Supergiant           7
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Name: count, dtype: int64

# %%
df['Team1']=df['Team1'].replace('Kings XI Punjab','Punjab Kings')

# %%
df['Team2']=df['Team2'].replace('Kings XI Punjab','Punjab Kings')

# %%
df['Team1'].value_counts()
# Out:
# Team1
# Royal Challengers Bangalore    126
# Mumbai Indians                 112
# Chennai Super Kings            111
# Punjab Kings                   110
# Kolkata Knight Riders          105
# Rajasthan Royals                89
# Delhi Daredevils                85
# Sunrisers Hyderabad             69
# Deccan Chargers                 39
# Delhi Capitals                  29
# Pune Warriors                   23
# Gujarat Lions                   16
# Lucknow Super Giants             8
# Gujarat Titans                   7
# Rising Pune Supergiant           7
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Name: count, dtype: int64

# %%
df['WinningTeam']=df['WinningTeam'].replace('Kings XI Punjab','Punjab Kings')

# %%
df['WinningTeam'].value_counts()
# Out:
# WinningTeam
# Mumbai Indians                 131
# Chennai Super Kings            121
# Kolkata Knight Riders          114
# Royal Challengers Bangalore    109
# Punjab Kings                   101
# Rajasthan Royals                96
# Sunrisers Hyderabad             75
# Delhi Daredevils                67
# Delhi Capitals                  36
# Deccan Chargers                 29
# Gujarat Lions                   13
# Gujarat Titans                  12
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Lucknow Super Giants             9
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
df['TossWinner']=df['TossWinner'].replace('Kings XI Punjab','Punjab Kings')

# %%
df.TossWinner.value_counts()
# Out:
# TossWinner
# Mumbai Indians                 123
# Kolkata Knight Riders          114
# Chennai Super Kings            109
# Royal Challengers Bangalore    105
# Rajasthan Royals                99
# Punjab Kings                    94
# Delhi Daredevils                80
# Sunrisers Hyderabad             74
# Deccan Chargers                 43
# Delhi Capitals                  36
# Pune Warriors                   20
# Gujarat Lions                   15
# Gujarat Titans                  10
# Kochi Tuskers Kerala             8
# Lucknow Super Giants             7
# Rising Pune Supergiants          7
# Rising Pune Supergiant           6
# Name: count, dtype: int64

# %%
df['Team1']=df['Team1'].replace('Delhi Darredevils','Delhi capital')
df['Team2']=df['Team2'].replace('Delhi Darredevils','Delhi capital')
df['WinningTeam']=df['WinningTeam'].replace('Delhi Darredevils','Delhi capital')

# %%
df['Team1']=df['Team1'].replace('Rising Pune Supergiants','Rising Pune Supergiant')
df['Team2']=df['Team2'].replace('Rising Pune Supergiants','Rising Pune Supergiant')
df['WinningTeam']=df['WinningTeam'].replace('Rising Pune Supergiants','Rising Pune Supergiant')

# %% [markdown]
# Dealing with null value

# %%
df.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
# city 
df['City'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 945    False
# 946    False
# 947    False
# 948    False
# 949    False
# Name: City, Length: 950, dtype: bool

# %%
C1 = df['City'].isnull()
df[C1].nunique()
# Out:
# ID                 51
# City                0
# Date               45
# Season              2
# MatchNumber        42
# Team1               9
# Team2               9
# Venue               2
# TossWinner          8
# TossDecision        2
# SuperOver           2
# WinningTeam         9
# WonBy               3
# Margin             26
# method              0
# Player_of_Match    38
# Team1Players       51
# Team2Players       49
# Umpire1            13
# Umpire2            10
# dtype: int64

# %%
C1 = df['City'].isnull()
df[C1]['Venue'].value_counts()
# Out:
# Venue
# Dubai International Cricket Stadium    33
# Sharjah Cricket Stadium                18
# Name: count, dtype: int64

# %%
vf =(df['Venue']=='Dubai International Cricket Stadium')
df[vf]['City']
# Out:
# 74     Dubai
# 77     Dubai
# 78     Dubai
# 81     Dubai
# 84     Dubai
# 86     Dubai
# 89     Dubai
# 91     Dubai
# 94     Dubai
# 96     Dubai
# 101    Dubai
# 102    Dubai
# 104    Dubai
# 134      NaN
# 137      NaN
# 140      NaN
# 142      NaN
# 145      NaN
# 147      NaN
# 150      NaN
# 151      NaN
# 154      NaN
# 156      NaN
# 159      NaN
# 160      NaN
# 164      NaN
# 165      NaN
# 167      NaN
# 170      NaN
# 172      NaN
# 175      NaN
# 176      NaN
# 180      NaN
# 182      NaN
# 184      NaN
# 187      NaN
# 188      NaN
# 191      NaN
# 192      NaN
# 532      NaN
# 534      NaN
# 539      NaN
# 540      NaN
# 542      NaN
# 546      NaN
# 547      NaN
# Name: City, dtype: object

# %%
vf =(df['Venue']=='Dubai International Cricket Stadium')

df[vf]['City']='Dubai'

# %%
df['City'].replace('')
# Out:
# 0       Ahmedabad
# 1       Ahmedabad
# 2         Kolkata
# 3         Kolkata
# 4          Mumbai
#           ...
# 945       Kolkata
# 946        Mumbai
# 947         Delhi
# 948    Chandigarh
# 949     Bangalore
# Name: City, Length: 950, dtype: object

# %%
# city 
c1=df['City'].isnull()
df[c1]['Venue'].value_counts()
#-----
# Out:
# Venue
# Dubai International Cricket Stadium    33
# Sharjah Cricket Stadium                18
# Name: count, dtype: int64

# %%
vf1 = (df['Venue'] == 'Sharjah Cricket Stadium')
df.loc[vf1,'City'] = 'Sharjah'

# %%
df.isnull().sum()
# Out:
# ID                   0
# City                33
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
df['SuperOver'].fillna('NoResult',inplace=True)
df['WinningTeam'].fillna('NoResult',inplace=True)
df['Player_of_Match'].fillna('NoResult',inplace= True)
df['Margin'].fillna('NoMargin',inplace = True)

# %%
df.isnull().sum()
# Out:
# ID                   0
# City                33
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            0
# WinningTeam          0
# WonBy                0
# Margin               0
# method             931
# Player_of_Match      0
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
df.drop(columns=['method'],inplace=True)

# %% [markdown]
# Date has been cleaned for further processing

# %%
df.coloumns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21868\2425176728.py in ?()
# ----> 1 df.coloumns
#
# c:\Users\klemp\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'coloumns'

# %%
df.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# 3             Eden Gardens, Kolkata        Gujarat Titans        field
# 4          Wankhede Stadium, Mumbai   Sunrisers Hyderabad          bat
#
#   SuperOver                  WinningTeam    WonBy Margin Player_of_Match  \
# 0         N               Gujarat Titans  Wickets    7.0       HH Pandya
# 1         N             Rajasthan Royals  Wickets    7.0      JC Buttler
# 2         N  Royal Challengers Bangalore     Runs   14.0      RM Patidar
# 3         N               Gujarat Titans  Wickets    7.0       DA Miller
# 4         N                 Punjab Kings  Wickets    5.0   Harpreet Brar
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
#
#                                         Team2Players        Umpire1  \
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2  ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4  ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
#
#          Umpire2
# 0    Nitin Menon
# 1    Nitin Menon
# 2       MA Gough
# 3      VK Sharma
# 4  NA Patwardhan

# %%
dfb=df

# %%
dfb['Innings'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\klemp\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Innings'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 dfb['Innings'].value_counts()
#
# File c:\Users\klemp\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\klemp\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Innings'

# %%
dfb.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# 3             Eden Gardens, Kolkata        Gujarat Titans        field
# 4          Wankhede Stadium, Mumbai   Sunrisers Hyderabad          bat
#
#   SuperOver                  WinningTeam    WonBy Margin Player_of_Match  \
# 0         N               Gujarat Titans  Wickets    7.0       HH Pandya
# 1         N             Rajasthan Royals  Wickets    7.0      JC Buttler
# 2         N  Royal Challengers Bangalore     Runs   14.0      RM Patidar
# 3         N               Gujarat Titans  Wickets    7.0       DA Miller
# 4         N                 Punjab Kings  Wickets    5.0   Harpreet Brar
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
#
#                                         Team2Players        Umpire1  \
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2  ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4  ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
#
#          Umpire2
# 0    Nitin Menon
# 1    Nitin Menon
# 2       MA Gough
# 3      VK Sharma
# 4  NA Patwardhan

# %%
dfb.value_counts()
# Out:
# ID       City        Date        Season   MatchNumber  Team1                        Team2                        Venue                                       TossWinner                   TossDecision  SuperOver  WinningTeam                  WonBy    Margin  Player_of_Match  Team1Players                                                                                                                                                Team2Players                                                                                                                                                  Umpire1      Umpire2
# 1312200  Ahmedabad   2022-05-29  2022     Final        Rajasthan Royals             Gujarat Titans               Narendra Modi Stadium, Ahmedabad            Rajasthan Royals             bat           N          Gujarat Titans               Wickets  7.0     HH Pandya        ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Ashwin', 'R Parag', 'TA Boult', 'OC McCoy', 'M Prasidh Krishna', 'YS Chahal']     ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']  CB Gaffaney  Nitin Menon       1
# 335982   Bangalore   2008-04-18  2007/08  1            Royal Challengers Bangalore  Kolkata Knight Riders        M Chinnaswamy Stadium                       Royal Challengers Bangalore  field         N          Kolkata Knight Riders        Runs     140.0   BB McCullum      ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis', 'CL White', 'MV Boucher', 'B Akhil', 'AA Noffke', 'P Kumar', 'Z Khan', 'SB Joshi']                         ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'DJ Hussey', 'Mohammad Hafeez', 'LR Shukla', 'WP Saha', 'AB Agarkar', 'AB Dinda', 'M Kartik', 'I Sharma']         Asad Rauf    RE Koertzen       1
# 335989   Chennai     2008-04-23  2007/08  8            Chennai Super Kings          Mumbai Indians               MA Chidambaram Stadium, Chepauk             Mumbai Indians               field         N          Chennai Super Kings          Runs     6.0     ML Hayden        ['PA Patel', 'ML Hayden', 'MEK Hussey', 'SK Raina', 'MS Dhoni', 'JDP Oram', 'S Badrinath', 'Joginder Sharma', 'P Amarnath', 'MS Gony', 'M Muralitharan']    ['L Ronchi', 'ST Jayasuriya', 'RV Uthappa', 'SM Pollock', 'DJ Bravo', 'AM Nayar', 'MA Khote', 'Harbhajan Singh', 'A Nehra', 'VS Yeligati', 'DS Kulkarni']     DJ Harper    GA Pratapkumar    1
# 335988   Hyderabad   2008-04-22  2007/08  7            Deccan Chargers              Delhi Daredevils             Rajiv Gandhi International Stadium, Uppal   Deccan Chargers              bat           N          Delhi Daredevils             Wickets  9.0     V Sehwag         ['AC Gilchrist', 'Y Venugopal Rao', 'VVS Laxman', 'A Symonds', 'RG Sharma', 'Shahid Afridi', 'SB Bangar', 'AS Yadav', 'WPUJC Vaas', 'RP Singh', 'PP Ojha']  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'Shoaib Malik', 'KD Karthik', 'MK Tiwary', 'R Bhatia', 'MF Maharoof', 'Mohammad Asif', 'VY Mahesh', 'GD McGrath']       IL Howell    AM Saheba         1
# 335987   Jaipur      2008-04-21  2007/08  6            Rajasthan Royals             Punjab Kings                 Sawai Mansingh Stadium                      Punjab Kings                 bat           N          Rajasthan Royals             Wickets  6.0     SR Watson        ['M Kaif', 'Kamran Akmal', 'YK Pathan', 'SR Watson', 'DS Lehmann', 'RA Jadeja', 'Pankaj Singh', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']         ['K Goel', 'JR Hopes', 'KC Sangakkara', 'DPMD Jayawardene', 'Yuvraj Singh', 'IK Pathan', 'S Sohal', 'B Lee', 'PP Chawla', 'WA Mota', 'S Sreesanth']           Aleem Dar    RB Tiffin         1
# Name: count, Length: 917, dtype: int64

# %%
dfb.nunique()
# Out:
# ID                 950
# City                33
# Date               706
# Season              15
# MatchNumber         80
# Team1               16
# Team2               16
# Venue               49
# TossWinner          17
# TossDecision         2
# SuperOver            3
# WinningTeam         17
# WonBy                4
# Margin              95
# Player_of_Match    263
# Team1Players       932
# Team2Players       937
# Umpire1             58
# Umpire2             60
# dtype: int64

# %%
dfb.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'Player_of_Match', 'Team1Players', 'Team2Players',
#        'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
dfb['BattingTeam'].value_counts().sort_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\klemp\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'BattingTeam'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 dfb['BattingTeam'].value_Counts().sort_index()
#
# File c:\Users\klemp\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\klemp\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'BattingTeam'
